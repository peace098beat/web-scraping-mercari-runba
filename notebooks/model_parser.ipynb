# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks")

# %%
df = pd.read_csv("./data/imac_model_map.csv")

display(df.head(29))
# Out:
#         catch_name        Model_Name ModelA    year     ModelB  \
# 0         Mid 2021      iMac 24 inch      -  2021.0   MGPD3J/A
# 1              NaN               NaN      -     NaN   MGPN3J/A
# 2              NaN               NaN      -     NaN   MGPL3J/A
# 3              NaN               NaN      -     NaN   MGPJ3J/A
# 4              NaN               NaN      -     NaN   MGPM3J/A
# 5              NaN               NaN      -     NaN   MGPK3J/A
# 6              NaN               NaN      -     NaN   MGPH3J/A
# 7              NaN               NaN      -     NaN   MGPC3J/A
# 8              NaN               NaN      -     NaN   MJVA3J/A
# 9              NaN               NaN      -     NaN   MJV83J/A
# 10             NaN               NaN      -     NaN   MJV93J/A
# 11             NaN               NaN      -     NaN   MGTF3J/A
# 12  Mid 2021 北米モデル      iMac 24 inch  A2438  2021.0  MGPD3LL/A
# 13             NaN               NaN    NaN     NaN  MGPN3LL/A
# ...

# %%
df_filled = df.fillna(method="ffill")
df_filled.to_csv("./data/imac_model_map_filled.csv", index=False)

display(df_filled.head(29))
# Out:
#         catch_name        Model_Name ModelA    year     ModelB  \
# 0         Mid 2021      iMac 24 inch      -  2021.0   MGPD3J/A
# 1         Mid 2021      iMac 24 inch      -  2021.0   MGPN3J/A
# 2         Mid 2021      iMac 24 inch      -  2021.0   MGPL3J/A
# 3         Mid 2021      iMac 24 inch      -  2021.0   MGPJ3J/A
# 4         Mid 2021      iMac 24 inch      -  2021.0   MGPM3J/A
# 5         Mid 2021      iMac 24 inch      -  2021.0   MGPK3J/A
# 6         Mid 2021      iMac 24 inch      -  2021.0   MGPH3J/A
# 7         Mid 2021      iMac 24 inch      -  2021.0   MGPC3J/A
# 8         Mid 2021      iMac 24 inch      -  2021.0   MJVA3J/A
# 9         Mid 2021      iMac 24 inch      -  2021.0   MJV83J/A
# 10        Mid 2021      iMac 24 inch      -  2021.0   MJV93J/A
# 11        Mid 2021      iMac 24 inch      -  2021.0   MGTF3J/A
# 12  Mid 2021 北米モデル      iMac 24 inch  A2438  2021.0  MGPD3LL/A
# 13  Mid 2021 北米モデル      iMac 24 inch  A2438  2021.0  MGPN3LL/A
# ...
