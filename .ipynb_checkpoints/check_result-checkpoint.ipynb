# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# !ls
# Out:
# Untitled.ipynb     img                main3.py           mercari_imac.xlsx
# check_result.ipynb main1.py           main4.py
# chromedriver       main2.py           mercari-imac.csv

# %%
df = pd.read_csv("mercari-imac.csv", header=None)
df.columns = ["name", "price", "dummy", "url"]

df = df[["name", "price"]]

# %%
df
# Out:
#                                                   name  price
# 0                       iMac 2012 21.5 Inchの画像 18,800円  18800
# 1                          Apple imac A1224の画像 15,000円  15000
# 2         APPLE iMac IMAC本体のみ MC508J/A ジャンク品の画像 5,000円   5000
# 3                             【中古】Apple iMacの画像 8,000円   8000
# 4                Apple iMac 　アップル　デスクトップパソコンの画像 9,999円   9999
# ..                                                 ...    ...
# 115  Apple iMac デスクトップPC (21.5-inch Mid 2010)の画像 16...  16000
# 116                     iMac early 2009 ジャンクの画像 6,500円   6500
# 117   iMac 箱24-inch A2438 Z12V0005B Apple 外箱の画像 5,500円   5500
# 118                              Apple iMacの画像 15,000円  15000
# 119                       Apple iMac 21.5インチの画像 9,500円   9500
#
# [120 rows x 2 columns]

# %%
df.price.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
import re
keywords = []
for r in df.name:
    r = r.replace("【", " ").replace("】", " ").replace("の画像", " ")
    r = r.replace(",", " ")
    r = r.replace("[", " ").replace("]", " ").replace("インチ", "inch")
    r = re.sub(',|、|。', ' ', r)
    r = r.lower()
    ws = [s.strip() for s in r.split()]
    keywords += ws
keywords
pd.Series(keywords).unique()
# Out:
# array(['imac', '2012', '21.5', 'inch', '18', '800円', 'apple', 'a1224',
#        '15', '000円', 'imac本体のみ', 'mc508j/a', 'ジャンク品', '5', '中古', '8',
#        'アップル', 'デスクトップパソコン', '9', '999円', '(27-inch.', 'mid', '2011)',
#        'a1311', '500円', 'i', 'mac', '27inch', '(late', '2012)', 'mouse',
#        '&キーボード付き', 'imac（21.5-inch', '2011）メモリ8gbへ増設済', '27型', '1tb',
#        'core', 'i3', '700円', 'パソコンimac(21.5-inch', '2010)', '200円',
#        'a1312', '内蔵パーツ', '⑤メイン基板マザーボード', '16gb', 'office', 'イラレ付', '4gb',
#        '500gb', '14', '2011', '2009', '300円', '21.5inch', 'el', 'capitan',
#        '11', '値下げ', 'late2009', '400円', '3.06ghz', 'mid2010', '250円',
#        '266', 'ストロベリー', '10', 'late', '初代', 'dv400', 'ブルー', '動作確認済み',
#        '希少', 'レトロ', '555円', 'apple-imac', '(27inch)', '※ジャンク品＆ソフトケース',
#        '※お値下げ中', '6', '100円', '2010', 'corei3', '+', 'magic', 'keyboard',
#        '19', '2017', 'intel', 'i5', '3.0ghz', '動いてるジャンク部品取', '12', 'i7',
#        'g3', '画面左上丸い傷跡あり！］imac', '21.5inc', '2015', '「ジャンク」', '2010年モデル',
#        'ブルーベリー', 'インテリア', 'セール!', '2010年bicで新品購入', '150円', 'mc309j/a',
#        '2015late', 'ddr3', '純正メモリ', '16gb分（8gb×2）', 'ジャンク', '20-inch',
#        '2007', '444円', '初期化済み', '20', '初代imac', 'キーボードとマウス', '240円',
#        '動作良好', '(20inch', 'early', '2009)', 'os10.10.5', 'md093j/a', 'g5',
#        '7', 'a1225｜24inch｜3.06ghz｜ssd', '250gb｜美品', 'モデルa1225', '24inch',
#        '本体のみ', '(21.5-inch', '2013)', '8gb', '液晶割れ', '13', '(mid',
#        'early2009', 'leopard', '20inch', '21.5inchlate', 'ssd', 'チェンジ',
#        '2002', 'm6498', '15inch', 'mid2011', '21.5-inch', 'ma876j/a',
#        '16', '(retina', '5k', '27-inch', '2015)', '動きません',
#        '部品取りにどうでしょうか？知識無いので', '型式不明でですがimac', 'mb418j/a', 'カスタム', '17',
#        '600円', 'ハイシェラ10.13.6', 'dv', 'se', 'グラファイト', 'mid2011)', '888円',
#        'mc510j/a', '☘️apple', 'me086', '画面欠けあり', 'モニター', 'ジャンク扱い',
#        '2007年モデル', 'アイマック', '2008', 'ssd512g中古', 'g3ライム', 'グリーン',
#        '21.5inch(late', '中古ssd組換品', 'cdドライブ付', 'mc309kh/a', '韓国版',
#        'ワイヤレスキーボード', 'マジックマウス付', '900円', '2.4ghz', 'osxインストール済', 'パープル',
#        'mb952j/a', '一体型', 'pc', 'retina', '4k', '(early', '2019)',
#        'imac（early', '2009）20inch', 'g4', 'osx10.4', 'junk', 'デスクトップ',
#        '51-sa0830-02', '27', '＋ケーブル', '純正', '動作不可', '部品取り推奨', 'ma877j/a',
#        '2007)', '320gb', 'メモリ4gb', 'mc812j/a', 'hdd', 'メモリ16gb',
#        '2009late', '中古品', '動作ok', '21.4inch.', 'mid-2011', 'メモリ12gb',
#        '純正キーボード・マウス付', '紫色', '起動品', 'power', '333m', '送料込', '21inch',
#        '2.5ghz', '空箱', 'me088j/a', '液晶カーバーガラス割れた', '2.66ghz', '2', 'duo',
#        '21.5i', '490円', '2009年モデル', 'imac☆ジャンクです', '350円', '2014',
#        '220819-2', 'mc509j/a', 'ボンダイブルー', '動作品', '#11', 'デスクトップpc',
#        '箱24-inch', 'a2438', 'z12v0005b', '外箱'], dtype=object)

# %%
x  = "20インチ Apple iMac デスクトップPC (21.5-inch Mid 2010)の画像 A2021 16.."
print(x)
x = x.lower()
re.findall("20\d\d", x)
re.findall("20\d\d", x)
re.findall("a20\d\d", x)
# Out:
# 20インチ Apple iMac デスクトップPC (21.5-inch Mid 2010)の画像 A2021 16..
# ['a2021']

# %%
def parse_inch(x):
    x = x.lower()
    import re
    x = re.sub('20..', '【---】 ', x)
    x = re.sub('a1...', '【---】 ', x)
    x = re.sub('a2...', '【---】 ', x)

    for y in (20, 21.5, 24, 27):
        if str(y) in x : 
            return y
    
    return None

df["size"] = df["name"].apply(parse_inch)
df.sample(20)
# Out:
#                                                   name  price  size
# 92   APPLE アップル iMac アイマック IMAC MC508J/A 2010の画像 11...  11800   NaN
# 50      APPLE iMac IMAC  21.5-inch mid 2010の画像 12,400円  12400  21.5
# 3                             【中古】Apple iMacの画像 8,000円   8000   NaN
# 97   iMac  21.5インチ LATE  2012    Apple  アイマックの画像 20...  20000  21.5
# 85   iMac MA877J/A  (Mid 2007)　320GB  メモリ4GBの画像 9,999円   9999   NaN
# 72   Apple iMac 21.5インチ　ワイヤレスキーボード　マジックマウス付の画像 15,900円  15900  21.5
# 27                                   imac g3の画像 9,000円   9000   NaN
# 20           Apple  iMac A1312　27インチ【ジャンク品】の画像 10,500円  10500  27.0
# 31      【値下げ】Apple iMac   ブルーベリー　ジャンク品　インテリアの画像 9,200円   9200   NaN
# 109    【ジャンク】APPLE iMac 21.5-inch, Mid 2014の画像 13,000円  13000  21.5
# 32   セール! Apple iMac 21.5inch 2010年BICで新品購入の画像 18,150円  18150  21.5
# 38                          初代iMac キーボードとマウスの画像 5,240円   5240  24.0
# 52   iMac (Retina 5K,27-inch,Late 2015) 純正メモリの画像 8,...   8300  27.0
# 2         APPLE iMac IMAC本体のみ MC508J/A ジャンク品の画像 5,000円   5000   NaN
# 7    i Mac 27インチ (Late 2012)  Mouse &キーボード付きの画像 18,...  18000  27.0
# 118                              Apple iMacの画像 15,000円  15000   NaN
# 82          Apple iMac (21.5-inch,Late 2009)の画像 9,800円   9800  21.5
# 100      Apple iMac 2.5GHz 21.5インチ MC309J/Aの画像 20,000円  20000  21.5
# 112          apple アップル 初代 iMac ボンダイブルー 動作品の画像 17,000円  17000   NaN
# 77                    iMac（Early 2009）20インチの画像 12,500円  12500   NaN

# %%
x = " ".join(keywords)
s = re.findall(r"\d+(?:\.\d+)?ghz", x.lower())
print(s)

def parse_cpu(x):
    x = x.lower()
    s = re.findall(r"\d+(?:\.\d+)?ghz", x.lower())
    if len(s) == 0:
        return None
    elif len(s) == 1:
        return s[0]
    else:
        return " ".join(s)

df["cpu_GHz"] = df["name"].apply(parse_cpu)
df.sort_values("cpu_GHz")
# Out:
# ['3.06ghz', '3.0ghz', '3.06ghz', '2.4ghz', '2.5ghz', '2.66ghz']
#                                                   name  price  size  cpu_GHz
# 73    Apple iMac a1224 2.4Ghz 4GB OSXインストール済の画像 6,300円   6300   NaN   2.4ghz
# 100      Apple iMac 2.5GHz 21.5インチ MC309J/Aの画像 20,000円  20000  21.5   2.5ghz
# 103  Apple iMac 2009 2.66GHz core 2 Duo 21.5iの画像 5,...   5490  21.5  2.66ghz
# 18   Apple iMac 21.5 3.06GHz Mid2010 MC508J/Aの画像 11...  11250  21.5  3.06ghz
# 42   【 iMac 】A1225｜24インチ｜3.06GHz｜SSD 250GB｜美品の画像 11...  11000  24.0  3.06ghz
# ..                                                 ...    ...   ...      ...
# 115  Apple iMac デスクトップPC (21.5-inch Mid 2010)の画像 16...  16000  21.5     None
# 116                     iMac early 2009 ジャンクの画像 6,500円   6500   NaN     None
# 117   iMac 箱24-inch A2438 Z12V0005B Apple 外箱の画像 5,500円   5500  24.0     None
# 118                              Apple iMacの画像 15,000円  15000   NaN     None
# 119                       Apple iMac 21.5インチの画像 9,500円   9500  21.5     None
#
# [120 rows x 4 columns]

# %%
def parse_cpu(x):
    x = x.lower()
    for y in ("i3", "i5", "i7", "duo"):
        if str(y) in x : 
            return y
    
    return None

df["cpu"] = df["name"].apply(parse_cpu)
df.sample(30).sort_values("cpu")
# Out:
#                                                   name  price  size  cpu_GHz  \
# 26   Imac A1312 27インチ　27型 Core i7 中古　27inchの画像 18,500円  18500  27.0     None
# 112          apple アップル 初代 iMac ボンダイブルー 動作品の画像 17,000円  17000   NaN     None
# 47     Apple iMac 21.5インチlate 2009 SSD チェンジの画像 15,000円  15000  21.5     None
# 18   Apple iMac 21.5 3.06GHz Mid2010 MC508J/Aの画像 11...  11250  21.5  3.06ghz
# 60                 iMac (21.5-inch mid2011)の画像 18,888円  18888  21.5     None
# 70                                      iMacの画像 9,888円   9888   NaN     None
# 66      初代iMac G3ライム グリーン ジャンク品 apple アイマックの画像 10,000円  10000   NaN     None
# 1                          Apple imac A1224の画像 15,000円  15000   NaN     None
# 97   iMac  21.5インチ LATE  2012    Apple  アイマックの画像 20...  20000  21.5     None
# 13     APPLE iMac 27インチ　27inch 4GB 500GB 中古の画像 14,700円  14700  27.0     None
# 113              【ジャンク品】APPLE iMac 24インチ　#11の画像 7,000円   7000  24.0     None
# 105                             iMac☆ジャンクです。の画像 6,000円   6000   NaN     None
# 45             【ジャンク】iMac  27インチ (Mid 2011)の画像 10,000円  10000  27.0     None
# 86           APPLE iMac IMAC MC812J/A【ジャンク品】の画像 9,600円   9600   NaN     None
# 48                     2002 iMac M6498 15インチの画像 9,000円   9000   NaN     None
# 0                       iMac 2012 21.5 Inchの画像 18,800円  18800  21.5     None
# 76   【ジャンク品】iMac Retina 4K 21.5 (Early 2019)の画像 20,...  20000  21.5     None
# 42   【 iMac 】A1225｜24インチ｜3.06GHz｜SSD 250GB｜美品の画像 11...  11000  24.0  3.06ghz
# 32   セール! Apple iMac 21.5inch 2010年BICで新品購入の画像 18,150円  18150  21.5     None
# 11       iMac 27インチ A1312 内蔵パーツ ⑤メイン基板マザーボードの画像 5,800円   5800  27.0     None
# 6                                 iMac A1311の画像 8,500円   8500   NaN     None
# 91         iMac 21.5inch Mid 2010  中古品 動作OKの画像 12,000円  12000  21.5     None
# 19                          iMAC 266 ストロベリーの画像 11,800円  11800   NaN     None
# 55                iMac mid2011 21.5インチ カスタムの画像 17,600円  17600  21.5     None
# 12         iMac 2012 21.5 16GB  office イラレ付の画像 15,800円  15800  21.5     None
# 64           iMac 2007年モデル ジャンク品 apple アイマックの画像 8,000円   8000   NaN     None
# 96           iMac 21.5 Mid2011 純正キーボード・マウス付の画像 15,000円  15000  21.5     None
# 90                          APPLE iMac IMACの画像 16,000円  16000   NaN     None
# 77                    iMac（Early 2009）20インチの画像 12,500円  12500   NaN     None
# 4                Apple iMac 　アップル　デスクトップパソコンの画像 9,999円   9999   NaN     None
#
#       cpu
# 26     i7
# 112  None
# 47   None
# 18   None
# 60   None
# 70   None
# 66   None
# 1    None
# 97   None
# 13   None
# 113  None
# 105  None
# 45   None
# 86   None
# 48   None
# 0    None
# 76   None
# 42   None
# 32   None
# 11   None
# 6    None
# 91   None
# 19   None
# 55   None
# 12   None
# 64   None
# 96   None
# 90   None
# 77   None
# 4    None

# %%
def parse_mem(x):
    s = re.findall(r"\d+(?:\.\d+)?gb", x.lower())
    s = [float(a.replace("gb", "")) for a in s]
    s.sort(reverse=True)
    for GB in s:
        if float(GB) < 100:
            return GB
        
df["mem"] = df["name"].apply(parse_mem)
df.sample(100).sort_values("mem")
# Out:
#                                                   name  price  size cpu_GHz  \
# 13     APPLE iMac 27インチ　27inch 4GB 500GB 中古の画像 14,700円  14700  27.0    None
# 73    Apple iMac a1224 2.4Ghz 4GB OSXインストール済の画像 6,300円   6300   NaN  2.4ghz
# 95                          iMac  24インチ　8GBの画像 20,000円  20000  24.0    None
# 44   iMac (21.5-inch, Late 2013) 8GB 1TB 液晶割れの画像 13...  13000  21.5    None
# 8      iMac（21.5-inch , Mid 2011）メモリ8GBへ増設済の画像 15,000円  15000  21.5    None
# ..                                                 ...    ...   ...     ...
# 25    Imac 2017 Intel i5 3.0GHz 動いてるジャンク部品取の画像 12,000円  12000   NaN  3.0ghz
# 102   APPLE iMac IMAC ME088J/A 液晶カーバーガラス割れたの画像 17,000円  17000   NaN    None
# 9    Apple Imac 27inch 27インチ　27型 1TB  Core i3の画像 15...  15700  27.0    None
# 90                          APPLE iMac IMACの画像 16,000円  16000   NaN    None
# 59                iMac (21.5-inch,Mid 2011)の画像 14,500円  14500  21.5    None
#
#       cpu  mem
# 13   None  4.0
# 73   None  4.0
# 95   None  8.0
# 44   None  8.0
# 8    None  8.0
# ..    ...  ...
# 25     i5  NaN
# 102  None  NaN
# 9      i3  NaN
# 90   None  NaN
# 59   None  NaN
#
# [100 rows x 6 columns]

# %%
x = " ".join(keywords)
s = re.findall(r"\d+(?:\.\d+)?gb", x.lower())
print(s)



def parse_vol(x):
    s = re.findall(r"\d+(?:\.\d+)?gb", x.lower())
    for m in s:
        GB = m.replace("gb", "")
        if float(GB) > 100:
            # hdd
            return GB
        
df["volume"] = df["name"].apply(parse_vol)
df.sample(100).sort_values("volume")
# Out:
# ['8gb', '16gb', '4gb', '500gb', '16gb', '8gb', '250gb', '8gb', '4gb', '320gb', '4gb', '16gb', '12gb', '8gb']
#                                                  name  price  size  cpu_GHz  \
# 42  【 iMac 】A1225｜24インチ｜3.06GHz｜SSD 250GB｜美品の画像 11...  11000  24.0  3.06ghz
# 85  iMac MA877J/A  (Mid 2007)　320GB  メモリ4GBの画像 9,999円   9999   NaN     None
# 13    APPLE iMac 27インチ　27inch 4GB 500GB 中古の画像 14,700円  14700  27.0     None
# 83                         imac 2011 27inchの画像 9,500円   9500  27.0     None
# 25   Imac 2017 Intel i5 3.0GHz 動いてるジャンク部品取の画像 12,000円  12000   NaN   3.0ghz
# ..                                                ...    ...   ...      ...
# 78  APPLE iMac G4 m6498 osx10.4 15inch JUNKの画像 13,...  13000   NaN     None
# 62          ☘️Apple iMac 21.5 me086 画面欠けありの画像 18,000円  18000  21.5     None
# 49                   iMac 21.5inch Mid2011の画像 19,800円  19800  21.5     None
# 89                    iMac 2009late 21.5インチの画像 8,600円   8600  21.5     None
# 15                     APPLE iMac IMAC 2009の画像 9,300円   9300   NaN     None
#
#      cpu  mem volume
# 42  None  NaN    250
# 85  None  4.0    320
# 13  None  4.0    500
# 83  None  NaN   None
# 25    i5  NaN   None
# ..   ...  ...    ...
# 78  None  NaN   None
# 62  None  NaN   None
# 49  None  NaN   None
# 89  None  NaN   None
# 15  None  NaN   None
#
# [100 rows x 7 columns]

# %%
def parse_ssd(x):
    return str("ssd") in x.lower()

df["ssd"] = df["name"].apply(parse_ssd)
df.sample(100).sort_values("ssd")
# Out:
#                                                   name  price  size  cpu_GHz  \
# 44   iMac (21.5-inch, Late 2013) 8GB 1TB 液晶割れの画像 13...  13000  21.5     None
# 67                  iMac 21.5インチ(Late 2009)の画像 17,000円  17000  21.5     None
# 92   APPLE アップル iMac アイマック IMAC MC508J/A 2010の画像 11...  11800   NaN     None
# 80                       Apple iMac 21.5インチの画像 16,500円  16500  21.5     None
# 108                APPLE iMac IMAC MC309J/Aの画像 17,500円  17500   NaN     None
# ..                                                 ...    ...   ...      ...
# 48                     2002 iMac M6498 15インチの画像 9,000円   9000   NaN     None
# 100      Apple iMac 2.5GHz 21.5インチ MC309J/Aの画像 20,000円  20000  21.5   2.5ghz
# 42   【 iMac 】A1225｜24インチ｜3.06GHz｜SSD 250GB｜美品の画像 11...  11000  24.0  3.06ghz
# 47     Apple iMac 21.5インチlate 2009 SSD チェンジの画像 15,000円  15000  21.5     None
# 69            【中古SSD組換品】iMac 27inch CDドライブ付の画像 16,500円  16500  27.0     None
#
#       cpu  mem volume    ssd
# 44   None  8.0   None  False
# 67   None  NaN   None  False
# 92   None  NaN   None  False
# 80   None  NaN   None  False
# 108  None  NaN   None  False
# ..    ...  ...    ...    ...
# 48   None  NaN   None  False
# 100  None  NaN   None  False
# 42   None  NaN    250   True
# 47   None  NaN   None   True
# 69   None  NaN   None   True
#
# [100 rows x 8 columns]

# %%
def parse_年式(x):
    for y in range(2001, 2030):
        if str(y) in x : 
            return int(y)
    
    return None

df["year"] = df["name"].apply(parse_年式)
df.sample(10)
# Out:
#                                                   name  price  size cpu_GHz  \
# 62           ☘️Apple iMac 21.5 me086 画面欠けありの画像 18,000円  18000  21.5    None
# 53   動きません。部品取りにどうでしょうか？知識無いので、型式不明でですがIMAC。の画像 10,...  10000   NaN    None
# 5                  iMac (27-inch. Mid 2011)の画像 18,000円  18000  27.0    None
# 72   Apple iMac 21.5インチ　ワイヤレスキーボード　マジックマウス付の画像 15,900円  15900  21.5    None
# 60                 iMac (21.5-inch mid2011)の画像 18,888円  18888  21.5    None
# 52   iMac (Retina 5K,27-inch,Late 2015) 純正メモリの画像 8,...   8300  27.0    None
# 114        【ジャンク】iMac (21.5-inch, Mid 2011)の画像 10,500円  10500  21.5    None
# 88                 iMac i5  HDD 1TB メモリ16GBの画像 19,000円  19000   NaN    None
# 101                          iMac 21.5インチ　空箱の画像 6,900円   6900  21.5    None
# 108                APPLE iMac IMAC MC309J/Aの画像 17,500円  17500   NaN    None
#
#       cpu   mem volume    ssd    year
# 62   None   NaN   None  False     NaN
# 53   None   NaN   None  False     NaN
# 5    None   NaN   None  False  2011.0
# 72   None   NaN   None  False     NaN
# 60   None   NaN   None  False  2011.0
# 52   None   NaN   None  False  2015.0
# 114  None   NaN   None  False  2011.0
# 88     i5  16.0   None  False     NaN
# 101  None   NaN   None  False     NaN
# 108  None   NaN   None  False     NaN

# %%
df["ジャンク"] = df["name"].str.contains("ジャンク")
df
# Out:
#                                                   name  price  size cpu_GHz  \
# 0                       iMac 2012 21.5 Inchの画像 18,800円  18800  21.5    None
# 1                          Apple imac A1224の画像 15,000円  15000   NaN    None
# 2         APPLE iMac IMAC本体のみ MC508J/A ジャンク品の画像 5,000円   5000   NaN    None
# 3                             【中古】Apple iMacの画像 8,000円   8000   NaN    None
# 4                Apple iMac 　アップル　デスクトップパソコンの画像 9,999円   9999   NaN    None
# ..                                                 ...    ...   ...     ...
# 115  Apple iMac デスクトップPC (21.5-inch Mid 2010)の画像 16...  16000  21.5    None
# 116                     iMac early 2009 ジャンクの画像 6,500円   6500   NaN    None
# 117   iMac 箱24-inch A2438 Z12V0005B Apple 外箱の画像 5,500円   5500  24.0    None
# 118                              Apple iMacの画像 15,000円  15000   NaN    None
# 119                       Apple iMac 21.5インチの画像 9,500円   9500  21.5    None
#
#       cpu  mem volume    ssd    year   ジャンク
# 0    None  NaN   None  False  2012.0  False
# 1    None  NaN   None  False     NaN  False
# 2    None  NaN   None  False     NaN   True
# 3    None  NaN   None  False     NaN  False
# 4    None  NaN   None  False     NaN  False
# ..    ...  ...    ...    ...     ...    ...
# 115  None  NaN   None  False  2010.0  False
# 116  None  NaN   None  False  2009.0   True
# 117  None  NaN   None  False     NaN  False
# 118  None  NaN   None  False     NaN  False
# 119  None  NaN   None  False     NaN  False
#
# [120 rows x 10 columns]

# %%
df
# Out:
#                                                   name  price  size cpu_GHz  \
# 0                       iMac 2012 21.5 Inchの画像 18,800円  18800  21.5    None
# 1                          Apple imac A1224の画像 15,000円  15000   NaN    None
# 2         APPLE iMac IMAC本体のみ MC508J/A ジャンク品の画像 5,000円   5000   NaN    None
# 3                             【中古】Apple iMacの画像 8,000円   8000   NaN    None
# 4                Apple iMac 　アップル　デスクトップパソコンの画像 9,999円   9999   NaN    None
# ..                                                 ...    ...   ...     ...
# 115  Apple iMac デスクトップPC (21.5-inch Mid 2010)の画像 16...  16000  21.5    None
# 116                     iMac early 2009 ジャンクの画像 6,500円   6500   NaN    None
# 117   iMac 箱24-inch A2438 Z12V0005B Apple 外箱の画像 5,500円   5500  24.0    None
# 118                              Apple iMacの画像 15,000円  15000   NaN    None
# 119                       Apple iMac 21.5インチの画像 9,500円   9500  21.5    None
#
#       cpu  mem volume    ssd    year   ジャンク
# 0    None  NaN   None  False  2012.0  False
# 1    None  NaN   None  False     NaN  False
# 2    None  NaN   None  False     NaN   True
# 3    None  NaN   None  False     NaN  False
# 4    None  NaN   None  False     NaN  False
# ..    ...  ...    ...    ...     ...    ...
# 115  None  NaN   None  False  2010.0  False
# 116  None  NaN   None  False  2009.0   True
# 117  None  NaN   None  False     NaN  False
# 118  None  NaN   None  False     NaN  False
# 119  None  NaN   None  False     NaN  False
#
# [120 rows x 10 columns]

# %%
import seaborn as sns

# %%
ax = sns.swarmplot(data=df, x="price", hue="ジャンク")
